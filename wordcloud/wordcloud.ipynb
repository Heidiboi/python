# %%
# !pip install wordcloud

# %% [markdown]
# 1. 워드클라우드 관련 모듈 가져오기

# %%
from wordcloud import WordCloud
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# 2. 데이터 가져오기

# %%
import requests
res = requests.get('http://ggoreb.com/python/file/날개.txt') #주소를 바꿔도됨
#res = requests.get('http://ggoreb.com/quiz/Harry_poter.txt')
res.encoding = None
text = res.text

# %% [markdown]
# 3. 워드클라우드 외형으로 사용할 Mask 불러오기

# %%
# mask = np.array(Image.open('bird.png'))

icon = Image.open('apple.png')# 투명 사진 있으면 사용가능
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon, icon)
mask = np.array(mask)

# %% [markdown]
# 4. 워드클라우드 객체 생성

# %%
wordcloud = WordCloud(
  font_path='c:/windows/fonts/gulim.ttc', 
  background_color='white',
  mask=mask).generate(text)

# %% [markdown]
# 5. 워드클라우드 표시

# %%
plt.figure(figsize=(6, 6))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
plt.savefig# 다운도 가능
# Out:
# <function matplotlib.pyplot.savefig(*args, **kwargs)>
